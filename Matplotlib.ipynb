# %% [markdown]
# <a href="https://colab.research.google.com/github/Wilson7774/AprendiendoGit/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Visualización de datos
# Matplotlib

# %%
pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
valores = np.array([14,23,48,35])
plt.plot(valores)
plt.show()

# %%
valoresX = np.array([4,5,8,9])
valoresY = np.array([9,7,4,8])
plt.plot(valoresX,valoresY)
plt.show()

# %%
valoresX = np.array([4,5,8,9])
valoresY = np.array([9,7,4,8])
plt.plot(valoresX,valoresY,"pr")
plt.show()

# %%
valoresX = np.array([4,5,8,9])
valoresY = np.array([9,7,4,8])
plt.plot(valoresX,valoresY,linewidth=5)
plt.show()

# %%
valoresX = np.array([4,5,8,9])
valoresY = np.array([9,7,4,8])
plt.plot(valoresX,valoresY,"--",linewidth=3)
plt.show()

# %%
valoresX = np.random.randint(low=1, high=100, size=20)
valoresY = np.random.randint(low=1, high=100, size=20)
plt.plot(valoresX,valoresY,"co")

valoresX2 = np.random.randint(low=1, high=100, size=20)
valoresY2 = np.random.randint(low=1, high=100, size=20)
plt.plot(valoresX2,valoresY2,"vg")
plt.show()

# %%
# Histogramas

# %%
valores =  np.random.randn(1000)
plt. hist(valores)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
valores =  np.random.randn(1000)
plt. hist(valores,orientation="horizontal",color="red")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
valores =  np.random.randn(1000)
plt. hist(valores, range=(-1,1))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
valores1 =  np.random.randn(1000)
valores2 =  np.random.randn(1000)
plt.hist2d(valores1,valores2)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Gráficos de barras

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
valoresX = ["a","b","c","d","e"]
valoresY = np.random.randint(low=1, high=20,size=5)
ax.bar(valoresX,valoresY)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
datos1 = np.random.randint(low=1, high=20,size=5)
datos2 = np.random.randint(low=1, high=20,size=5)
nDatos = 5

fig.ax = plt.subplots( )
index = np.arange(nDatos)
barWidth = 0.35
barras1 = plt.bar(index, datos1, barWidth, color= "r", label = "Antes de clase")
barras2 = plt.bar(index+barWidth, datos2, barWidth, color= "g", label = "Despues de clase")
plt.xlabel("Fases")
plt.ylabel("Puntuación")
plt.title("Mejoras en los estudaintes")
plt.xticksindex+barWidth("Wilson", "Fernando", "José", "Pedro", "Juan")
plt.leyend()
plt.tight-layout()
plt.show
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f887a9b73bb7> in <cell line: 13>()
#      11 plt.ylabel("Puntuación")
#      12 plt.title("Mejoras en los estudaintes")
# ---> 13 plt.xticksindex+barWidth("Wilson", "Fernando", "José", "Pedro", "Juan")
#      14 plt.leyend()
#      15 plt.tight-layout()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'xticksindex'

# %% [markdown]
# Gráficos circulares

# %%
valores = np.array([0.2,.15,.14,.10,0.05])
plt.pie(valores)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
valores = np.array([0.2,.15,.14,.10,0.05])
lables = ["Pedro", "Pablo","Juan","Oscar","Milton"]
plt.pie(valores, labels= lables, radius= 2.0)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
figura = plt.gcf()
figura.set_size_inches(30,10)

plt.subplot(131)
valores = np.array([0.2,0.15,0.34,0.10,0.05,0.16])
lables = ['Pedro','Pablo','Oscar','Juan','José','Miltón']
plt.pie(valores, labels=lables)

plt.subplot(132)
valores1 = np.random.randn(1000)
valores2 = np.random.randn(1000)
plt.hist2d(valores1,valores2)

plt.subplot(133)
valX1 = np.random.randint(low=1,high=100, size=20)
valY1 = np.random.randint(low=1,high=100, size=20)
plt.plot(valX1,valY1,'co')

valX1 = np.random.randint(low=1,high=100, size=20)
valY1 = np.random.randint(low=1,high=100, size=20)
plt.plot(valX1,valY1,'vr')

plt.savefig("Gráfica final png")
